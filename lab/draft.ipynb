# %% [markdown]
# draft code for lab coding

# %%
if __name__ == "__main__":
    import numpy as np
    import matplotlib.pyplot as plt

    npts = 4
    xgrid = np.linspace(0, 1, npts)

# %%
import numpy as np
x = np.array([0, 1, 2, 3]).reshape(-1, 1)
print(x)
x = x.reshape(-1)
print(x)
# Out:
# [[0]
#  [1]
#  [2]
#  [3]]
# [0 1 2 3]
